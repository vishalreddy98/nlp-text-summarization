# %% [markdown]
# ### **1. Install and Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from tqdm import tqdm
import torch
import warnings
warnings.filterwarnings('ignore')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
! pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %% [markdown]
# ### **2. Load the test data**

# %%
from datasets import load_from_disk
tokenized_dataset_test = load_from_disk("/content/drive/MyDrive/wikihow_data/T5small_test_tokenized")

# %%
import pandas as pd
dataset = pd.DataFrame()

# %%
dataset['text'] = tokenized_dataset_test['text']
dataset['headline'] = tokenized_dataset_test['headline']

# %%
dataset
# Out:
#                                                    text  \
# 0     Caged animals such as hamsters, guinea pigs, r...
# 1     Every boarding barn has people who go on vacat...
# 2     Let him know that you like him by making an ef...
# 3     It can be hard to tell if someone is intereste...
# 4     Your crush may be the prettiest person in the ...
# ...                                                 ...
# 5572  ;\n, If you're having trouble with the seatbel...
# 5573  Listen for the click or other sound it makes w...
# 5574  Each class corresponds to a letter of the alph...
# 5575  Brake pads and brake shoes are different from ...
# 5576  You will need to purchase either a 1/2 inch or...
#
#                                                headline
# 0     Relocate your caged pet.\nChoose an environmen...
# 1     Horse-sit.\nHire yourself out as a groomer.\nT...
# 2     Pay attention to your appearance.\nShow him ho...
# 3     Read the signs.\nInvite him along on a group a...
# 4     Get to know your crush a bit.\nHang out in per...
# ...                                                 ...
# 5572  Find someone you feel comfortable with to go o...
# 5573  Double check your harness, bar or other restra...
# 5574  Learn the 20 classifications the Library of Co...
# 5575  Learn the difference between brake pads and br...
# 5576  Gather your materials.\nPrepare your yarn.\nAr...
#
# [5577 rows x 2 columns]

# %%
dataset['text'][0]
# Out:
# "Caged animals such as hamsters, guinea pigs, rodent, reptiles, and amphibians can be taken to a friend's or sitter's home. Create a document that outlines the feeding and water needs, cleaning schedule, and temperature control. Pack all of the things that mimic your pet's environment at your home such as bedding, heated surfaces, and decorations.If the cage is not mobile, someone will need to come check on your pet daily.\n A rabbit, ferret, or guinea pig is live bait in the wild. Relocating your pet to a home with canines or young children can be stressful and dangerous for your pet. If your pet is used to being in a quiet home with only adults, find a place that mimics that.The relocation environment is extremely important. Your pet can become disoriented and possibly sick from sudden lifestyle changes.\n Birds and cats enjoy being in consistent, familiar environments. Birds may become restless and pluck their own feathers in unfamiliar environments. Similarly, cats can become distressed in different environments. It's best to find a sitter to stay in your home or stop by your home every day.\n\n\nIf you have a bird, make sure that the sitter is comfortable and knowledgeable about birds.\nCats should not be left alone at someone else's home. They are likely to wander, escape, and try to return home.\n A kennel should be the last resort for this type of pet. Make sure the kennel you choose caters to your pet. If your pet will be at a kennel that also houses dogs and cats, it is best if it will be housed in a separate area. Always check out the kennel before you allow your pet to stay there.\n\n\nAsk your veterinarian about boarding options for this type of pet. Some veterinarians provide boarding services as well."

# %%
dataset['headline'][0]
# Out:
# 'Relocate your caged pet.\nChoose an environment that is similar to your home.\nGet an in-home sitter for birds and cats.\nTake your pet to a kennel.'

# %%
X_test, y_test = dataset['text'], dataset['headline']

# %% [markdown]
# ### **3. Define Metrics Utility Functions**

# %%
# Set the locale to UTF-8
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=63489e12c7a59a4f5ab8159104a5826d50f003c2c3fc5054a1c629232a367e5a
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer

def getmetrics(dataset,model_summaries):
  # Sample references and hypotheses
  references = [ref.split() for ref in dataset['headline']]

  if model_summaries in ['T5_SFT_summary', 'T5_LoRA_summary']:
    hypotheses = [hyp[0]['summary_text'].split() for hyp in dataset[model_summaries]]
  else:
    hypotheses = [hyp.split() for hyp in dataset[model_summaries]]

# Calculate BLEU score
  bleu_scores = [sentence_bleu([ref], hyp) for ref, hyp in zip(references, hypotheses)]

# Calculate average BLEU score
  average_bleu = sum(bleu_scores) / len(bleu_scores)

  print(f"Average BLEU Score: {average_bleu * 100:.2f}")
  # Assuming 'reference_summary' and 'hypothesis_summary' are Pandas Series
  references = dataset['headline'].astype(str).tolist()
  hypotheses = dataset[model_summaries].astype(str).tolist()

# Create a RougeScorer instance
  scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeLsum'], use_stemmer=True)

# Calculate ROUGE scores for each pair of reference and hypothesis
  rouge_scores = []
  for ref, hyp in zip(references, hypotheses):
    scores = scorer.score(ref, hyp)
    rouge_scores.append(scores)

# Print the scores for the first pair (adjust as needed)
  print("ROUGE-1 F1 Score:", rouge_scores[0]['rouge1'].fmeasure)
  print("ROUGE-2 F1 Score:", rouge_scores[0]['rouge2'].fmeasure)
  print("ROUGE-L F1 Score:", rouge_scores[0]['rougeLsum'].fmeasure)

# %%
prediction = pd.read_pickle('/content/drive/MyDrive/wikihow_data/predictions_all.pkl')

# %% [markdown]
# ### **4. Making Predictions**

# %% [markdown]
# #### **LSTM**

# %%
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
LSTM_model = tf.keras.models.load_model("/content/drive/MyDrive/Models/wikihow-lstm.h5")

# %%
tokenizer_doc = Tokenizer()
tokenizer_doc.fit_on_texts(X_test)
sequences_doc = tokenizer_doc.texts_to_sequences(X_test)

tokenizer_sum = Tokenizer()
tokenizer_sum.fit_on_texts(y_test)
sequences_sum = tokenizer_sum.texts_to_sequences(y_test)

X_test_padded = pad_sequences(sequences_doc, maxlen=2667, padding='post')
y_test_padded = pad_sequences(sequences_sum, maxlen=200, padding='post')

# %%
import numpy as np
batch_size = 8
num_batches = len(X_test_padded) // batch_size

y_pred_texts = []

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    # Extract a batch of input sequences
    batch_padded_doc = X_test_padded[start_idx:end_idx]

    # Generate predictions for the batch
    batch_predicted_summary_sequences = LSTM_model.predict(batch_padded_doc)

    # Get word indices
    batch_word_indices = np.argmax(batch_predicted_summary_sequences, axis=-1)

    # Convert indices to words
    batch_y_pred_texts = [tokenizer_sum.sequences_to_texts([seq])[0] for seq in batch_word_indices]

    # Extend the result list
    y_pred_texts.extend(batch_y_pred_texts)

# If there's a remainder (i.e., len(padded_doc) is not a multiple of batch_size), process the remaining samples
if len(X_test_padded) % batch_size != 0:
    remainder_start_idx = num_batches * batch_size
    remainder_padded_doc = X_test_padded[remainder_start_idx:]

    remainder_predicted_summary_sequences = LSTM_model.predict(remainder_padded_doc)
    remainder_word_indices = np.argmax(remainder_predicted_summary_sequences, axis=-1)
    remainder_y_pred_texts = [tokenizer_sum.sequences_to_texts([seq])[0] for seq in remainder_word_indices]

    y_pred_texts.extend(remainder_y_pred_texts)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 82ms/step

# %%
prediction['LSTM_summary'] = y_pred_texts

# %%
prediction.to_pickle('/content/drive/MyDrive/wikihow_data/predictions_all.pkl')

# %% [markdown]
# #### **T5 Small/BART Base(Without Finetuning)**

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
# Load your pre-trained model and tokenizer
#checkpoint = "t5-small"
checkpoint = "facebook/bart-base"
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
sampled_df = dataset

# Specify the batch size
batch_size = 20

# Tokenize the sampled dataset with a progress bar
tokenized_batches = []

num_batches = int(np.ceil(len(sampled_df) / batch_size))

for i in tqdm(range(0, len(sampled_df), batch_size), total=num_batches, desc="Tokenizing"):
    # Extract a batch of articles from the sampled dataset
    batch_articles = sampled_df['text'][i:i + batch_size].tolist()


    #batch_articles = ["summarize: " + article for article in batch_articles] #Not Required for BART

    # Tokenize the batch with padding and truncation
    batch_tokenized = tokenizer(batch_articles, max_length=1024, truncation=True, padding="max_length", return_tensors="pt")

    # Check for inconsistent tensor sizes and filter them out
    valid_indices = [j for j in range(len(batch_articles)) if batch_tokenized['input_ids'][j].size(0) == 1024]

    # If all tensors have the expected size, append the batch
    if len(valid_indices) == len(batch_articles):
        tokenized_batches.append(batch_tokenized)
    else:
        print(f"Excluding batch at index {i} due to inconsistent tensor sizes.")

# Concatenate the valid batches
tokenized_dataset = {}
for key in tokenized_batches[0].keys():
    tokenized_dataset[key] = torch.cat([batch[key] for batch in tokenized_batches], dim=0)
# Out:
# Tokenizing: 100%|██████████| 279/279 [00:13<00:00, 21.29it/s]

# %%
# Move the model to the GPU
model = model.to("cuda")

# Define batch size for inference
batch_size = 20

# Initialize an empty list to store decoded summaries
decoded_summaries = []
processed_indices = []

# Use tqdm to create a progress bar
for i in tqdm(range(0, len(tokenized_dataset["input_ids"]), batch_size), desc="Generating Summaries", leave=False):
    batch_inputs = {key: value[i:i + batch_size].to('cuda') for key, value in tokenized_dataset.items()}

    # Perform inference on the batch using the GPU
    with torch.no_grad():
        batch_outputs = model.generate(**batch_inputs)

    # Decode the generated summaries for the batch
    batch_decoded_summaries = tokenizer.batch_decode(batch_outputs, skip_special_tokens=True)
    decoded_summaries.extend(batch_decoded_summaries)

    # Keep track of the original indices
    batch_indices = sampled_df.index[i:i + batch_size].tolist()
    processed_indices.extend(batch_indices)

# %%
if len(processed_indices) == len(decoded_summaries):
    # Add the decoded summaries to your DataFrame using the processed indices
    sampled_df.loc[processed_indices, "BART_summaries"] = decoded_summaries
else:
    print("Error: Lengths do not match.")

print(len(sampled_df))
print(len(processed_indices))
print(len(decoded_summaries))
# Out:
# 5577
# 5577
# 5577

# %%
sampled_df.head()
# Out:
#                                                 text  \
# 0  Caged animals such as hamsters, guinea pigs, r...
# 1  Every boarding barn has people who go on vacat...
# 2  Let him know that you like him by making an ef...
# 3  It can be hard to tell if someone is intereste...
# 4  Your crush may be the prettiest person in the ...
#
#                                             headline  \
# 0  Relocate your caged pet.\nChoose an environmen...
# 1  Horse-sit.\nHire yourself out as a groomer.\nT...
# 2  Pay attention to your appearance.\nShow him ho...
# 3  Read the signs.\nInvite him along on a group a...
# 4  Get to know your crush a bit.\nHang out in per...
#
#                                       BART_summaries
# 0  Caged animals such as hamsters, guinea pigs, r...
# 1  Every boarding barn has people who go on vacat...
# 2  Let him know that you like him by making an ef...
# 3  It can be hard to tell if someone is intereste...
# 4  Your crush may be the prettiest person in the ...

# %%
import numpy as np

# Define a filtering criterion
def is_valid_summary(summary):
    return isinstance(summary, str) and summary.strip() != '' and len(set(summary)) > 1

# Apply the filter to create a subset of valid summaries
valid_summaries_df = sampled_df[sampled_df['BART_summaries'].apply(is_valid_summary)]

# %%
prediction['BART_summary'] = valid_summaries_df['BART_summaries']

# %%
prediction['T5_summary'] = valid_summaries_df['T5_summary']

# %%
prediction.to_pickle('/content/drive/MyDrive/wikihow_data/predictions_all.pkl')

# %% [markdown]
# #### **T5 Simple FineTuning**

# %%
from transformers import pipeline

t5simpleFT = pipeline("summarization", model="Prashanth-1998/wikihow_t5small_model", device=device)

# %%
tqdm.pandas(desc="Applying summarizer")
prediction['T5_SFT_summary'] = dataset['text'].progress_apply(t5simpleFT)
# Out:
# Applying summarizer:   0%|          | 3/600 [00:04<15:31,  1.56s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1207 > 512). Running this sequence through the model will result in indexing errors
# Applying summarizer:   1%|          | 6/600 [00:08<12:20,  1.25s/it]Your max_length is set to 200, but your input_length is only 173. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:   1%|▏         | 8/600 [00:09<09:02,  1.09it/s]Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:   2%|▏         | 11/600 [00:11<07:21,  1.33it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Applying summarizer:   6%|▋         | 38/600 [00:36<09:29,  1.01s/it]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:   8%|▊         | 50/600 [00:48<10:21,  1.13s/it]Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Applying summarizer:  16%|█▋        | 98/600 [01:29<06:19,  1.32it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  25%|██▌       | 152/600 [02:16<07:30,  1.01s/it]Your max_length is set to 200, but your input_length is only 184. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Applying summarizer:  30%|██▉       | 179/600 [02:41<07:49,  1.12s/it]Your max_length is set to 200, but your input_length is only 188. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# Applying summarizer:  30%|███       | 180/600 [02:41<06:44,  1.04it/s]Your max_length is set to 200, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Applying summarizer:  32%|███▏      | 192/600 [02:54<07:24,  1.09s/it]Your max_length is set to 200, but your input_length is only 156. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Applying summarizer:  32%|███▏      | 194/600 [02:56<07:22,  1.09s/it]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Applying summarizer:  35%|███▍      | 209/600 [03:06<04:42,  1.38it/s]Your max_length is set to 200, but your input_length is only 24. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Applying summarizer:  36%|███▌      | 216/600 [03:13<05:45,  1.11it/s]Your max_length is set to 200, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Applying summarizer:  36%|███▌      | 217/600 [03:13<05:02,  1.27it/s]Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  38%|███▊      | 226/600 [03:19<03:51,  1.61it/s]Your max_length is set to 200, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Applying summarizer:  38%|███▊      | 227/600 [03:19<03:30,  1.77it/s]Your max_length is set to 200, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Applying summarizer:  38%|███▊      | 229/600 [03:20<03:14,  1.91it/s]Your max_length is set to 200, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Applying summarizer:  40%|███▉      | 239/600 [03:28<04:18,  1.39it/s]Your max_length is set to 200, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Applying summarizer:  40%|████      | 241/600 [03:29<03:45,  1.59it/s]Your max_length is set to 200, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Applying summarizer:  46%|████▌     | 273/600 [03:58<05:09,  1.06it/s]Your max_length is set to 200, but your input_length is only 144. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Applying summarizer:  46%|████▌     | 277/600 [04:01<04:02,  1.33it/s]Your max_length is set to 200, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Applying summarizer:  49%|████▉     | 295/600 [04:16<04:01,  1.26it/s]Your max_length is set to 200, but your input_length is only 172. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  50%|████▉     | 299/600 [04:20<04:06,  1.22it/s]Your max_length is set to 200, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Applying summarizer:  57%|█████▋    | 340/600 [04:58<03:59,  1.09it/s]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Applying summarizer:  62%|██████▏   | 371/600 [05:27<03:50,  1.01s/it]Your max_length is set to 200, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# Applying summarizer:  62%|██████▏   | 373/600 [05:28<03:31,  1.07it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  64%|██████▍   | 387/600 [05:40<02:44,  1.29it/s]Your max_length is set to 200, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Applying summarizer:  67%|██████▋   | 404/600 [05:54<02:26,  1.34it/s]Your max_length is set to 200, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:  72%|███████▏  | 430/600 [06:16<02:54,  1.03s/it]Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Applying summarizer:  76%|███████▌  | 455/600 [06:38<01:56,  1.25it/s]Your max_length is set to 200, but your input_length is only 143. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Applying summarizer:  76%|███████▌  | 457/600 [06:39<01:47,  1.33it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  79%|███████▉  | 474/600 [06:53<01:33,  1.34it/s]Your max_length is set to 200, but your input_length is only 178. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Applying summarizer:  79%|███████▉  | 475/600 [06:54<01:25,  1.46it/s]Your max_length is set to 200, but your input_length is only 160. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  81%|████████  | 486/600 [07:03<02:03,  1.08s/it]Your max_length is set to 200, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Applying summarizer:  82%|████████▎ | 495/600 [07:11<01:26,  1.21it/s]Your max_length is set to 200, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer:  89%|████████▊ | 532/600 [07:44<00:50,  1.35it/s]Your max_length is set to 200, but your input_length is only 191. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  89%|████████▉ | 534/600 [07:45<00:52,  1.25it/s]Your max_length is set to 200, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Applying summarizer:  92%|█████████▏| 549/600 [07:59<00:48,  1.04it/s]Your max_length is set to 200, but your input_length is only 169. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  92%|█████████▏| 551/600 [08:01<00:41,  1.19it/s]Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Applying summarizer:  93%|█████████▎| 559/600 [08:08<00:32,  1.26it/s]Your max_length is set to 200, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Applying summarizer:  97%|█████████▋| 580/600 [08:25<00:15,  1.25it/s]Your max_length is set to 200, but your input_length is only 173. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  97%|█████████▋| 583/600 [08:28<00:14,  1.18it/s]Your max_length is set to 200, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Applying summarizer: 100%|██████████| 600/600 [08:43<00:00,  1.15it/s]

# %%
prediction.to_csv('/content/drive/MyDrive/wikihow_data/predictions.csv', index=False)

# %% [markdown]
# #### **T5 LoRA Finetuning**

# %%
t5LoRAFT = pipeline("summarization", model="rohitmacherla3/wikihow_t5small_LoRA_fine_tuned",device = device)

# %%
tqdm.pandas(desc="Applying summarizer")
prediction['T5_LoRA_summary'] = dataset['text'].progress_apply(t5LoRAFT)
# Out:
# Applying summarizer:   0%|          | 3/5577 [00:05<2:43:09,  1.76s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1207 > 512). Running this sequence through the model will result in indexing errors
# Applying summarizer:   0%|          | 6/5577 [00:11<3:34:35,  2.31s/it]Your max_length is set to 200, but your input_length is only 173. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:   0%|          | 8/5577 [00:14<2:53:24,  1.87s/it]Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:   1%|          | 38/5577 [00:36<54:38,  1.69it/s]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:   1%|          | 50/5577 [00:46<1:16:05,  1.21it/s]Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Applying summarizer:   2%|▏         | 98/5577 [01:20<1:00:46,  1.50it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:   3%|▎         | 152/5577 [02:05<1:42:29,  1.13s/it]Your max_length is set to 200, but your input_length is only 184. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Applying summarizer:   3%|▎         | 179/5577 [02:25<1:18:05,  1.15it/s]Your max_length is set to 200, but your input_length is only 188. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# Applying summarizer:   3%|▎         | 180/5577 [02:25<1:06:29,  1.35it/s]Your max_length is set to 200, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Applying summarizer:   3%|▎         | 192/5577 [02:36<1:08:38,  1.31it/s]Your max_length is set to 200, but your input_length is only 156. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Applying summarizer:   3%|▎         | 194/5577 [02:38<1:17:58,  1.15it/s]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Applying summarizer:   4%|▎         | 209/5577 [02:50<1:07:06,  1.33it/s]Your max_length is set to 200, but your input_length is only 24. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Applying summarizer:   4%|▍         | 216/5577 [02:54<1:00:49,  1.47it/s]Your max_length is set to 200, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Applying summarizer:   4%|▍         | 217/5577 [02:55<56:37,  1.58it/s]  Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:   4%|▍         | 226/5577 [03:01<1:08:44,  1.30it/s]Your max_length is set to 200, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Applying summarizer:   4%|▍         | 227/5577 [03:01<1:04:23,  1.38it/s]Your max_length is set to 200, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Applying summarizer:   4%|▍         | 229/5577 [03:03<1:01:54,  1.44it/s]Your max_length is set to 200, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Applying summarizer:   4%|▍         | 239/5577 [03:08<51:36,  1.72it/s]Your max_length is set to 200, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Applying summarizer:   4%|▍         | 241/5577 [03:10<50:06,  1.77it/s]Your max_length is set to 200, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Applying summarizer:   5%|▍         | 273/5577 [03:35<1:10:00,  1.26it/s]Your max_length is set to 200, but your input_length is only 144. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Applying summarizer:   5%|▍         | 277/5577 [03:38<1:04:58,  1.36it/s]Your max_length is set to 200, but your input_length is only 175. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=87)
# Applying summarizer:   5%|▌         | 295/5577 [03:53<1:02:29,  1.41it/s]Your max_length is set to 200, but your input_length is only 172. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:   5%|▌         | 299/5577 [03:55<57:13,  1.54it/s]Your max_length is set to 200, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Applying summarizer:   6%|▌         | 340/5577 [04:29<48:24,  1.80it/s]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Applying summarizer:   7%|▋         | 371/5577 [04:54<1:04:18,  1.35it/s]Your max_length is set to 200, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# Applying summarizer:   7%|▋         | 373/5577 [04:55<51:27,  1.69it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:   7%|▋         | 387/5577 [05:05<1:10:47,  1.22it/s]Your max_length is set to 200, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Applying summarizer:   7%|▋         | 404/5577 [05:18<1:12:21,  1.19it/s]Your max_length is set to 200, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:   8%|▊         | 430/5577 [05:37<58:20,  1.47it/s]Your max_length is set to 200, but your input_length is only 195. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=97)
# Applying summarizer:   8%|▊         | 455/5577 [05:56<58:03,  1.47it/s]Your max_length is set to 200, but your input_length is only 143. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Applying summarizer:   8%|▊         | 457/5577 [05:57<52:20,  1.63it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:   8%|▊         | 474/5577 [06:09<58:53,  1.44it/s]  Your max_length is set to 200, but your input_length is only 178. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Applying summarizer:   9%|▊         | 475/5577 [06:10<54:02,  1.57it/s]Your max_length is set to 200, but your input_length is only 160. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:   9%|▊         | 486/5577 [06:18<1:17:14,  1.10it/s]Your max_length is set to 200, but your input_length is only 183. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Applying summarizer:   9%|▉         | 495/5577 [06:26<1:01:20,  1.38it/s]Your max_length is set to 200, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer:  10%|▉         | 532/5577 [06:53<54:19,  1.55it/s]  Your max_length is set to 200, but your input_length is only 191. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  10%|▉         | 534/5577 [06:55<51:55,  1.62it/s]Your max_length is set to 200, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Applying summarizer:  10%|▉         | 549/5577 [07:06<1:19:12,  1.06it/s]Your max_length is set to 200, but your input_length is only 169. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  10%|▉         | 551/5577 [07:07<1:13:15,  1.14it/s]Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Applying summarizer:  10%|█         | 559/5577 [07:13<1:00:21,  1.39it/s]Your max_length is set to 200, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Applying summarizer:  10%|█         | 580/5577 [07:28<58:37,  1.42it/s]Your max_length is set to 200, but your input_length is only 173. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  10%|█         | 583/5577 [07:30<1:02:18,  1.34it/s]Your max_length is set to 200, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Applying summarizer:  11%|█         | 605/5577 [07:46<1:00:42,  1.37it/s]Your max_length is set to 200, but your input_length is only 189. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# Applying summarizer:  11%|█         | 606/5577 [07:47<52:10,  1.59it/s]  Your max_length is set to 200, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  11%|█         | 624/5577 [08:01<1:06:01,  1.25it/s]Your max_length is set to 200, but your input_length is only 199. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  11%|█▏        | 635/5577 [08:10<1:06:49,  1.23it/s]Your max_length is set to 200, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Applying summarizer:  12%|█▏        | 646/5577 [08:18<1:03:14,  1.30it/s]Your max_length is set to 200, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Applying summarizer:  12%|█▏        | 650/5577 [08:21<1:02:24,  1.32it/s]Your max_length is set to 200, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# Applying summarizer:  12%|█▏        | 656/5577 [08:25<55:46,  1.47it/s]Your max_length is set to 200, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer:  12%|█▏        | 663/5577 [08:30<49:40,  1.65it/s]Your max_length is set to 200, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  12%|█▏        | 689/5577 [08:48<56:21,  1.45it/s]Your max_length is set to 200, but your input_length is only 123. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  12%|█▏        | 692/5577 [08:50<1:03:09,  1.29it/s]Your max_length is set to 200, but your input_length is only 178. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Applying summarizer:  12%|█▏        | 695/5577 [08:52<1:02:16,  1.31it/s]Your max_length is set to 200, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Applying summarizer:  13%|█▎        | 720/5577 [09:10<1:05:59,  1.23it/s]Your max_length is set to 200, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Applying summarizer:  13%|█▎        | 726/5577 [09:13<47:21,  1.71it/s]Your max_length is set to 200, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Applying summarizer:  13%|█▎        | 752/5577 [09:30<54:04,  1.49it/s]Your max_length is set to 200, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Applying summarizer:  14%|█▎        | 758/5577 [09:33<47:58,  1.67it/s]Your max_length is set to 200, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  14%|█▍        | 769/5577 [09:42<1:10:55,  1.13it/s]Your max_length is set to 200, but your input_length is only 170. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# Applying summarizer:  14%|█▍        | 782/5577 [09:50<51:53,  1.54it/s]Your max_length is set to 200, but your input_length is only 168. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  14%|█▍        | 787/5577 [09:54<1:04:17,  1.24it/s]Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Applying summarizer:  14%|█▍        | 795/5577 [09:59<55:55,  1.43it/s]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  14%|█▍        | 804/5577 [10:04<41:00,  1.94it/s]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  14%|█▍        | 805/5577 [10:04<38:30,  2.07it/s]Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  15%|█▍        | 820/5577 [10:14<44:59,  1.76it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  15%|█▍        | 833/5577 [10:23<1:01:55,  1.28it/s]Your max_length is set to 200, but your input_length is only 154. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Applying summarizer:  15%|█▍        | 834/5577 [10:24<1:01:24,  1.29it/s]Your max_length is set to 200, but your input_length is only 192. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Applying summarizer:  15%|█▌        | 844/5577 [10:30<48:16,  1.63it/s]Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Applying summarizer:  15%|█▌        | 855/5577 [10:37<57:42,  1.36it/s]Your max_length is set to 200, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Applying summarizer:  15%|█▌        | 856/5577 [10:38<54:11,  1.45it/s]Your max_length is set to 200, but your input_length is only 177. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Applying summarizer:  15%|█▌        | 859/5577 [10:40<57:12,  1.37it/s]  Your max_length is set to 200, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Applying summarizer:  16%|█▌        | 885/5577 [10:58<49:32,  1.58it/s]Your max_length is set to 200, but your input_length is only 181. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  16%|█▌        | 889/5577 [10:59<39:04,  2.00it/s]Your max_length is set to 200, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Applying summarizer:  16%|█▌        | 891/5577 [11:00<38:09,  2.05it/s]Your max_length is set to 200, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer:  16%|█▌        | 896/5577 [11:03<40:49,  1.91it/s]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  16%|█▌        | 897/5577 [11:03<37:14,  2.09it/s]Your max_length is set to 200, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  16%|█▋        | 908/5577 [11:11<1:04:05,  1.21it/s]Your max_length is set to 200, but your input_length is only 135. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Applying summarizer:  16%|█▋        | 915/5577 [11:15<50:14,  1.55it/s]Your max_length is set to 200, but your input_length is only 151. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# Applying summarizer:  17%|█▋        | 924/5577 [11:20<44:54,  1.73it/s]Your max_length is set to 200, but your input_length is only 180. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  17%|█▋        | 926/5577 [11:21<39:22,  1.97it/s]Your max_length is set to 200, but your input_length is only 199. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  17%|█▋        | 939/5577 [11:29<48:02,  1.61it/s]Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  17%|█▋        | 955/5577 [11:39<55:10,  1.40it/s]Your max_length is set to 200, but your input_length is only 170. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# Applying summarizer:  17%|█▋        | 962/5577 [11:44<52:05,  1.48it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  17%|█▋        | 963/5577 [11:45<46:15,  1.66it/s]Your max_length is set to 200, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Applying summarizer:  17%|█▋        | 965/5577 [11:46<50:54,  1.51it/s]Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  17%|█▋        | 968/5577 [11:48<41:42,  1.84it/s]Your max_length is set to 200, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Applying summarizer:  18%|█▊        | 984/5577 [12:02<1:13:10,  1.05it/s]Your max_length is set to 200, but your input_length is only 21. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# Applying summarizer:  18%|█▊        | 985/5577 [12:02<1:01:13,  1.25it/s]Your max_length is set to 200, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Applying summarizer:  18%|█▊        | 991/5577 [12:07<1:02:47,  1.22it/s]Your max_length is set to 200, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Applying summarizer:  18%|█▊        | 996/5577 [12:10<57:16,  1.33it/s]  Your max_length is set to 200, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Applying summarizer:  18%|█▊        | 999/5577 [12:13<1:04:18,  1.19it/s]Your max_length is set to 200, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Applying summarizer:  18%|█▊        | 1000/5577 [12:13<57:30,  1.33it/s] Your max_length is set to 200, but your input_length is only 141. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# Applying summarizer:  19%|█▊        | 1039/5577 [12:45<1:19:45,  1.05s/it]Your max_length is set to 200, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  19%|█▊        | 1044/5577 [12:50<1:11:58,  1.05it/s]Your max_length is set to 200, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Applying summarizer:  19%|█▉        | 1052/5577 [12:55<59:07,  1.28it/s]Your max_length is set to 200, but your input_length is only 173. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  19%|█▉        | 1054/5577 [12:57<55:23,  1.36it/s]Your max_length is set to 200, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Applying summarizer:  19%|█▉        | 1072/5577 [13:08<58:42,  1.28it/s]Your max_length is set to 200, but your input_length is only 185. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Applying summarizer:  20%|█▉        | 1089/5577 [13:21<48:44,  1.53it/s]Your max_length is set to 200, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Applying summarizer:  20%|█▉        | 1090/5577 [13:21<43:13,  1.73it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  20%|█▉        | 1109/5577 [13:35<50:00,  1.49it/s]Your max_length is set to 200, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Applying summarizer:  20%|██        | 1117/5577 [13:42<1:08:07,  1.09it/s]Your max_length is set to 200, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Applying summarizer:  20%|██        | 1121/5577 [13:45<1:07:52,  1.09it/s]Your max_length is set to 200, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:  20%|██        | 1122/5577 [13:46<58:41,  1.27it/s]  Your max_length is set to 200, but your input_length is only 168. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  20%|██        | 1141/5577 [13:57<54:44,  1.35it/s]Your max_length is set to 200, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:  22%|██▏       | 1225/5577 [15:01<1:02:20,  1.16it/s]Your max_length is set to 200, but your input_length is only 191. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  22%|██▏       | 1237/5577 [15:10<54:34,  1.33it/s]Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Applying summarizer:  22%|██▏       | 1238/5577 [15:11<52:14,  1.38it/s]Your max_length is set to 200, but your input_length is only 182. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Applying summarizer:  23%|██▎       | 1261/5577 [15:30<55:10,  1.30it/s]Your max_length is set to 200, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Applying summarizer:  23%|██▎       | 1273/5577 [15:38<47:46,  1.50it/s]Your max_length is set to 200, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  23%|██▎       | 1287/5577 [15:48<52:46,  1.35it/s]Your max_length is set to 200, but your input_length is only 143. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Applying summarizer:  23%|██▎       | 1288/5577 [15:48<44:37,  1.60it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  24%|██▎       | 1317/5577 [16:09<52:18,  1.36it/s]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  24%|██▍       | 1341/5577 [16:30<53:44,  1.31it/s]Your max_length is set to 200, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:  24%|██▍       | 1342/5577 [16:30<51:30,  1.37it/s]Your max_length is set to 200, but your input_length is only 196. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# Applying summarizer:  24%|██▍       | 1343/5577 [16:31<47:48,  1.48it/s]Your max_length is set to 200, but your input_length is only 123. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  24%|██▍       | 1347/5577 [16:33<45:54,  1.54it/s]Your max_length is set to 200, but your input_length is only 163. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# Applying summarizer:  24%|██▍       | 1351/5577 [16:36<45:28,  1.55it/s]Your max_length is set to 200, but your input_length is only 177. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
# Applying summarizer:  24%|██▍       | 1355/5577 [16:38<41:51,  1.68it/s]Your max_length is set to 200, but your input_length is only 185. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Applying summarizer:  24%|██▍       | 1359/5577 [16:41<49:32,  1.42it/s]Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Applying summarizer:  24%|██▍       | 1363/5577 [16:44<47:40,  1.47it/s]Your max_length is set to 200, but your input_length is only 185. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=92)
# Applying summarizer:  24%|██▍       | 1364/5577 [16:44<44:39,  1.57it/s]Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Applying summarizer:  24%|██▍       | 1365/5577 [16:45<45:15,  1.55it/s]Your max_length is set to 200, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Applying summarizer:  25%|██▍       | 1369/5577 [16:48<52:12,  1.34it/s]Your max_length is set to 200, but your input_length is only 180. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  25%|██▍       | 1373/5577 [16:50<39:27,  1.78it/s]Your max_length is set to 200, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  25%|██▍       | 1375/5577 [16:51<37:10,  1.88it/s]Your max_length is set to 200, but your input_length is only 161. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=80)
# Applying summarizer:  25%|██▍       | 1377/5577 [16:52<37:37,  1.86it/s]Your max_length is set to 200, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  25%|██▍       | 1381/5577 [16:54<40:27,  1.73it/s]Your max_length is set to 200, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Applying summarizer:  25%|██▍       | 1387/5577 [16:58<48:24,  1.44it/s]Your max_length is set to 200, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Applying summarizer:  25%|██▍       | 1388/5577 [16:59<44:34,  1.57it/s]Your max_length is set to 200, but your input_length is only 157. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=78)
# Applying summarizer:  25%|██▍       | 1390/5577 [17:00<45:11,  1.54it/s]Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  25%|██▍       | 1393/5577 [17:02<51:22,  1.36it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  25%|██▌       | 1398/5577 [17:06<49:22,  1.41it/s]Your max_length is set to 200, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Applying summarizer:  25%|██▌       | 1405/5577 [17:10<35:36,  1.95it/s]Your max_length is set to 200, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Applying summarizer:  25%|██▌       | 1407/5577 [17:11<45:19,  1.53it/s]Your max_length is set to 200, but your input_length is only 168. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  25%|██▌       | 1418/5577 [17:19<48:11,  1.44it/s]Your max_length is set to 200, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Applying summarizer:  25%|██▌       | 1421/5577 [17:20<37:51,  1.83it/s]Your max_length is set to 200, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Applying summarizer:  25%|██▌       | 1422/5577 [17:21<33:49,  2.05it/s]Your max_length is set to 200, but your input_length is only 196. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=98)
# Applying summarizer:  26%|██▌       | 1425/5577 [17:22<39:07,  1.77it/s]Your max_length is set to 200, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Applying summarizer:  26%|██▌       | 1429/5577 [17:25<40:47,  1.69it/s]Your max_length is set to 200, but your input_length is only 154. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Applying summarizer:  26%|██▌       | 1431/5577 [17:26<38:29,  1.80it/s]Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  26%|██▌       | 1432/5577 [17:26<35:51,  1.93it/s]Your max_length is set to 200, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Applying summarizer:  26%|██▌       | 1435/5577 [17:28<38:58,  1.77it/s]Your max_length is set to 200, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Applying summarizer:  26%|██▌       | 1441/5577 [17:33<59:39,  1.16it/s]Your max_length is set to 200, but your input_length is only 169. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  26%|██▌       | 1443/5577 [17:34<44:24,  1.55it/s]Your max_length is set to 200, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Applying summarizer:  26%|██▌       | 1446/5577 [17:36<46:43,  1.47it/s]Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  26%|██▌       | 1453/5577 [17:41<45:03,  1.53it/s]Your max_length is set to 200, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Applying summarizer:  26%|██▌       | 1458/5577 [17:43<37:32,  1.83it/s]Your max_length is set to 200, but your input_length is only 132. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Applying summarizer:  26%|██▌       | 1459/5577 [17:44<40:22,  1.70it/s]Your max_length is set to 200, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Applying summarizer:  26%|██▌       | 1462/5577 [17:46<41:07,  1.67it/s]Your max_length is set to 200, but your input_length is only 189. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
# Applying summarizer:  26%|██▌       | 1463/5577 [17:46<43:50,  1.56it/s]Your max_length is set to 200, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# ...
# Applying summarizer:  92%|█████████▏| 5128/5577 [1:01:22<06:36,  1.13it/s]Your max_length is set to 200, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Applying summarizer:  92%|█████████▏| 5131/5577 [1:01:23<05:18,  1.40it/s]Your max_length is set to 200, but your input_length is only 38. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Applying summarizer:  92%|█████████▏| 5140/5577 [1:01:29<04:59,  1.46it/s]Your max_length is set to 200, but your input_length is only 154. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Applying summarizer:  92%|█████████▏| 5152/5577 [1:01:39<05:27,  1.30it/s]Your max_length is set to 200, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Applying summarizer:  92%|█████████▏| 5153/5577 [1:01:40<04:58,  1.42it/s]Your max_length is set to 200, but your input_length is only 186. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Applying summarizer:  93%|█████████▎| 5179/5577 [1:01:59<04:38,  1.43it/s]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  93%|█████████▎| 5183/5577 [1:02:01<03:53,  1.69it/s]Your max_length is set to 200, but your input_length is only 172. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  93%|█████████▎| 5184/5577 [1:02:01<03:49,  1.72it/s]Your max_length is set to 200, but your input_length is only 158. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
# Applying summarizer:  93%|█████████▎| 5187/5577 [1:02:03<03:36,  1.80it/s]Your max_length is set to 200, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Applying summarizer:  93%|█████████▎| 5189/5577 [1:02:04<03:22,  1.92it/s]Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  93%|█████████▎| 5197/5577 [1:02:10<05:15,  1.21it/s]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  93%|█████████▎| 5207/5577 [1:02:16<03:53,  1.59it/s]Your max_length is set to 200, but your input_length is only 168. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  93%|█████████▎| 5213/5577 [1:02:19<03:13,  1.88it/s]Your max_length is set to 200, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Applying summarizer:  94%|█████████▎| 5221/5577 [1:02:24<04:01,  1.47it/s]Your max_length is set to 200, but your input_length is only 171. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=85)
# Applying summarizer:  94%|█████████▎| 5223/5577 [1:02:25<03:54,  1.51it/s]Your max_length is set to 200, but your input_length is only 162. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=81)
# Applying summarizer:  94%|█████████▎| 5224/5577 [1:02:26<03:54,  1.50it/s]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Applying summarizer:  94%|█████████▎| 5225/5577 [1:02:27<03:30,  1.67it/s]Your max_length is set to 200, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Applying summarizer:  94%|█████████▍| 5234/5577 [1:02:32<04:04,  1.40it/s]Your max_length is set to 200, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Applying summarizer:  94%|█████████▍| 5245/5577 [1:02:39<03:45,  1.47it/s]Your max_length is set to 200, but your input_length is only 178. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Applying summarizer:  94%|█████████▍| 5248/5577 [1:02:42<04:07,  1.33it/s]Your max_length is set to 200, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  94%|█████████▍| 5259/5577 [1:02:48<03:20,  1.59it/s]Your max_length is set to 200, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Applying summarizer:  94%|█████████▍| 5261/5577 [1:02:49<03:28,  1.52it/s]Your max_length is set to 200, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  95%|█████████▍| 5271/5577 [1:02:57<03:43,  1.37it/s]Your max_length is set to 200, but your input_length is only 145. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Applying summarizer:  95%|█████████▍| 5274/5577 [1:02:58<03:12,  1.58it/s]Your max_length is set to 200, but your input_length is only 151. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# Applying summarizer:  95%|█████████▍| 5279/5577 [1:03:02<03:18,  1.50it/s]Your max_length is set to 200, but your input_length is only 180. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Applying summarizer:  95%|█████████▍| 5285/5577 [1:03:06<02:59,  1.63it/s]Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Applying summarizer:  95%|█████████▍| 5287/5577 [1:03:07<02:56,  1.64it/s]Your max_length is set to 200, but your input_length is only 169. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=84)
# Applying summarizer:  95%|█████████▍| 5296/5577 [1:03:13<03:03,  1.53it/s]Your max_length is set to 200, but your input_length is only 154. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Applying summarizer:  95%|█████████▌| 5320/5577 [1:03:31<03:10,  1.35it/s]Your max_length is set to 200, but your input_length is only 155. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=77)
# Applying summarizer:  95%|█████████▌| 5326/5577 [1:03:35<02:50,  1.47it/s]Your max_length is set to 200, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Applying summarizer:  96%|█████████▌| 5333/5577 [1:03:41<03:21,  1.21it/s]Your max_length is set to 200, but your input_length is only 127. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Applying summarizer:  96%|█████████▌| 5338/5577 [1:03:44<03:00,  1.32it/s]Your max_length is set to 200, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Applying summarizer:  96%|█████████▌| 5342/5577 [1:03:47<02:48,  1.40it/s]Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Applying summarizer:  96%|█████████▌| 5351/5577 [1:03:53<02:41,  1.40it/s]Your max_length is set to 200, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Applying summarizer:  96%|█████████▌| 5352/5577 [1:03:53<02:23,  1.57it/s]Your max_length is set to 200, but your input_length is only 172. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=86)
# Applying summarizer:  96%|█████████▌| 5359/5577 [1:03:59<02:56,  1.24it/s]Your max_length is set to 200, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Applying summarizer:  96%|█████████▌| 5361/5577 [1:04:00<02:45,  1.30it/s]Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Applying summarizer:  96%|█████████▋| 5374/5577 [1:04:08<02:02,  1.66it/s]Your max_length is set to 200, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer:  97%|█████████▋| 5390/5577 [1:04:21<02:17,  1.36it/s]Your max_length is set to 200, but your input_length is only 179. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=89)
# Applying summarizer:  97%|█████████▋| 5401/5577 [1:04:30<02:43,  1.08it/s]Your max_length is set to 200, but your input_length is only 191. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer:  97%|█████████▋| 5407/5577 [1:04:33<01:55,  1.48it/s]Your max_length is set to 200, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Applying summarizer:  97%|█████████▋| 5410/5577 [1:04:35<01:54,  1.45it/s]Your max_length is set to 200, but your input_length is only 167. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=83)
# Applying summarizer:  97%|█████████▋| 5415/5577 [1:04:39<01:49,  1.49it/s]Your max_length is set to 200, but your input_length is only 198. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer:  98%|█████████▊| 5447/5577 [1:05:01<01:54,  1.14it/s]Your max_length is set to 200, but your input_length is only 151. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=75)
# Applying summarizer:  99%|█████████▉| 5542/5577 [1:06:14<00:35,  1.02s/it]Your max_length is set to 200, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Applying summarizer: 100%|█████████▉| 5565/5577 [1:06:31<00:10,  1.19it/s]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Applying summarizer: 100%|█████████▉| 5566/5577 [1:06:32<00:08,  1.30it/s]Your max_length is set to 200, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Applying summarizer: 100%|█████████▉| 5573/5577 [1:06:37<00:02,  1.45it/s]Your max_length is set to 200, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Applying summarizer: 100%|█████████▉| 5575/5577 [1:06:38<00:01,  1.60it/s]Your max_length is set to 200, but your input_length is only 199. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=99)
# Applying summarizer: 100%|██████████| 5577/5577 [1:06:40<00:00,  1.39it/s]

# %%
prediction.to_pickle('/content/drive/MyDrive/wikihow_data/predictions_all.pkl')

# %% [markdown]
# ### **Predictions Review**

# %%
prediction.head()
# Out:
#                                                 text  \
# 0  Caged animals such as hamsters, guinea pigs, r...
# 1  Every boarding barn has people who go on vacat...
# 2  Let him know that you like him by making an ef...
# 3  It can be hard to tell if someone is intereste...
# 4  Your crush may be the prettiest person in the ...
#
#                                             headline  \
# 0  Relocate your caged pet.\nChoose an environmen...
# 1  Horse-sit.\nHire yourself out as a groomer.\nT...
# 2  Pay attention to your appearance.\nShow him ho...
# 3  Read the signs.\nInvite him along on a group a...
# 4  Get to know your crush a bit.\nHang out in per...
#
#                                  Transformer_summary  \
# 0                                         know risks
# 1  walk around park walk around park walk around ...
# 2  look like girls girls girls girls girls girls ...
# 3                                        talk friend
# 4  make sure person want make sure person want ma...
#
#                                       T5_SFT_summary  \
# 0  [{'summary_text': 'a kennel should be the last...
# 1  [{'summary_text': 'boarding your horse in a sh...
# 2  [{'summary_text': 'if you're talking to a guy,...
# 3  [{'summary_text': 'if a person is interested, ...
# 4  [{'summary_text': 'if you’re into a girl, tell...
#
#                                      T5_LoRA_summary  \
# 0  [{'summary_text': 'Caged animals can be taken ...
# 1  [{'summary_text': 'boarding barns offer to pul...
# 2  [{'summary_text': 'you can flirt subtly and wo...
# 3  [{'summary_text': 'some schools hold a "sadie ...
# 4  [{'summary_text': 'sally kohn: texting your cr...
#
#                                         BART_summary  \
# 0  Caged animals such as hamsters, guinea pigs, r...
# 1  Every boarding barn has people who go on vacat...
# 2  Let him know that you like him by making an ef...
# 3  It can be hard to tell if someone is intereste...
# 4  Your crush may be the prettiest person in the ...
#
#                                           T5_summary  \
# 0  . Make sure the kennel you choose caters to yo...
# 1                                    ,,,,,,,,,,,,,,,
# 2     , but don't be afraid to be a little sexy. Let
# 3  you want him to hang out with, and have a spec...
# 4  , and you can tell her that she loves you. you...
#
#                                    T5_Prompt_summary  \
# 0  a kennel should be the last resort for this ty...
# 1  boarding barns are a great way to earn income....
# 2  a guy can be a bit awkward when flirting with ...
# 3  if you want to get to know him before you ask ...
# 4  if you're a crush, make sure you like her pers...
#
#                                         LSTM_summary
# 0  consider the the the the the the the the the t...
# 1  consider the the the the the the the the the t...
# 2  consider the the the the the the the the the t...
# 3  consider the the the the the the the the the t...
# 4  consider the the the the the the the the the t...

# %%
prediction['headline']
# Out:
# 0       Relocate your caged pet.\nChoose an environmen...
# 1       Horse-sit.\nHire yourself out as a groomer.\nT...
# 2       Pay attention to your appearance.\nShow him ho...
# 3       Read the signs.\nInvite him along on a group a...
# 4       Get to know your crush a bit.\nHang out in per...
#                               ...
# 5572    Find someone you feel comfortable with to go o...
# 5573    Double check your harness, bar or other restra...
# 5574    Learn the 20 classifications the Library of Co...
# 5575    Learn the difference between brake pads and br...
# 5576    Gather your materials.\nPrepare your yarn.\nAr...
# Name: headline, Length: 5577, dtype: object

# %%
prediction['LSTM_summary']
# Out:
# 0       consider the the the the the the the the the t...
# 1       consider the the the the the the the the the t...
# 2       consider the the the the the the the the the t...
# 3       consider the the the the the the the the the t...
# 4       consider the the the the the the the the the t...
#                               ...
# 5572    consider the the the the the the the the the t...
# 5573    consider the the the the the the the the the t...
# 5574    consider the the the the the the the the the t...
# 5575    consider the the the the the the the the the t...
# 5576    consider the the the the the the the the the t...
# Name: LSTM_summary, Length: 5577, dtype: object

# %%
prediction['Transformer_summary']
# Out:
# 0                                              know risks
# 1       walk around park walk around park walk around ...
# 2       look like girls girls girls girls girls girls ...
# 3                                             talk friend
# 4       make sure person want make sure person want ma...
#                               ...
# 5572                                   call driver ticket
# 5573    place cigarette hold cigarette hold cigarette ...
# 5574                                     look handwriting
# 5575    look signs injury look signs injury look signs...
# 5576    gather supplies place place place place place ...
# Name: Transformer_summary, Length: 5577, dtype: object

# %%
prediction['BART_summary']
# Out:
# 0       Caged animals such as hamsters, guinea pigs, r...
# 1       Every boarding barn has people who go on vacat...
# 2       Let him know that you like him by making an ef...
# 3       It can be hard to tell if someone is intereste...
# 4       Your crush may be the prettiest person in the ...
#                               ...
# 5572    ; Also, If you're having trouble with the seat...
# 5573    Listen for the click or other sound it makes w...
# 5574    Each class corresponds to a letter of the alph...
# 5575    Brake pads and brake shoes are different from ...
# 5576    You will need to purchase either a 1/2 inch or...
# Name: BART_summary, Length: 5577, dtype: object

# %%
prediction['T5_summary']
# Out:
# 0       . Make sure the kennel you choose caters to yo...
# 1                                         ,,,,,,,,,,,,,,,
# 2          , but don't be afraid to be a little sexy. Let
# 3       you want him to hang out with, and have a spec...
# 4       , and you can tell her that she loves you. you...
#                               ...
# 5572    you feel like you need to get out of line for ...
# 5573    the ride. You can also relax and relax. You ca...
# 5574    , the more specific the classification is—and ...
# 5575    , and brake shoes are different from one anoth...
# 5576    yarn. Cut each strand at one continuous angle,...
# Name: T5_summary, Length: 5577, dtype: object

# %%
prediction['T5_Prompt_summary']
# Out:
# 0       a kennel should be the last resort for this ty...
# 1       boarding barns are a great way to earn income....
# 2       a guy can be a bit awkward when flirting with ...
# 3       if you want to get to know him before you ask ...
# 4       if you're a crush, make sure you like her pers...
#                               ...
# 5572    a ride like this will shake loose hats, sandal...
# 5573    'clicking' restraints are still safe and won't...
# 5574    the more numbers and letters contained in a ca...
# 5575    brake pads and brake shoes are different from ...
# 5576    you will need to purchase either a 1/2 inch or...
# Name: T5_Prompt_summary, Length: 5577, dtype: object

# %%
prediction['T5_SFT_summary']
# Out:
# 0       [{'summary_text': 'a kennel should be the last...
# 1       [{'summary_text': 'boarding your horse in a sh...
# 2       [{'summary_text': 'if you're talking to a guy,...
# 3       [{'summary_text': 'if a person is interested, ...
# 4       [{'summary_text': 'if you’re into a girl, tell...
#                               ...
# 5572    [{'summary_text': 'a ride like this will shake...
# 5573    [{'summary_text': ''clicking' restraints are s...
# 5574    [{'summary_text': 'the more numbers and letter...
# 5575    [{'summary_text': 'the brake pad is built for ...
# 5576    [{'summary_text': 'the length of the rod depen...
# Name: T5_SFT_summary, Length: 5577, dtype: object

# %%
prediction['T5_LoRA_summary']
# Out:
# 0       [{'summary_text': 'Caged animals can be taken ...
# 1       [{'summary_text': 'boarding barns offer to pul...
# 2       [{'summary_text': 'you can flirt subtly and wo...
# 3       [{'summary_text': 'some schools hold a "sadie ...
# 4       [{'summary_text': 'sally kohn: texting your cr...
#                               ...
# 5572    [{'summary_text': 'a ride like this will shake...
# 5573    [{'summary_text': ''clicking' restraints are s...
# 5574    [{'summary_text': 'the more numbers and letter...
# 5575    [{'summary_text': 'the brake pad is built for ...
# 5576    [{'summary_text': 'the length of the rod depen...
# Name: T5_LoRA_summary, Length: 5577, dtype: object

# %% [markdown]
# ### **Evaluating the Models using ROUGE and BLEU Scores**

# %% [markdown]
# **LSTM**

# %%
getmetrics(prediction,'LSTM_summary')
# Out:
# Average BLEU Score: 0.00
# ROUGE-1 F1 Score: 0.0
# ROUGE-2 F1 Score: 0.0
# ROUGE-L F1 Score: 0.0

# %% [markdown]
# **Seq2Seq Transformer**

# %%
getmetrics(prediction,'Transformer_summary')
# Out:
# Average BLEU Score: 0.00
# ROUGE-1 F1 Score: 0.0
# ROUGE-2 F1 Score: 0.0
# ROUGE-L F1 Score: 0.0

# %% [markdown]
# **BART-base Pre-trained**

# %%
getmetrics(prediction,'BART_summary')
# Out:
# Average BLEU Score: 0.09
# ROUGE-1 F1 Score: 0.10526315789473682
# ROUGE-2 F1 Score: 0.0
# ROUGE-L F1 Score: 0.10526315789473682

# %% [markdown]
# **T5-Small Pre-trained**

# %%
getmetrics(prediction,'T5_summary')
# Out:
# Average BLEU Score: 0.11
# ROUGE-1 F1 Score: 0.3
# ROUGE-2 F1 Score: 0.10526315789473684
# ROUGE-L F1 Score: 0.25

# %% [markdown]
# **T5-Small Pre-trained With prompt**

# %%
getmetrics(prediction,'T5_Prompt_summary')
# Out:
# Average BLEU Score: 0.10
# ROUGE-1 F1 Score: 0.2
# ROUGE-2 F1 Score: 0.05263157894736842
# ROUGE-L F1 Score: 0.2

# %% [markdown]
# **T5-Small Simple Fine-tuned**

# %%
getmetrics(prediction,'T5_SFT_summary')
# Out:
# Average BLEU Score: 0.37
# ROUGE-1 F1 Score: 0.2318840579710145
# ROUGE-2 F1 Score: 0.05970149253731344
# ROUGE-L F1 Score: 0.17391304347826086

# %% [markdown]
# **T5-small LoRA Fine-tuned**

# %%
getmetrics(prediction,'T5_LoRA_summary')
# Out:
# Average BLEU Score: 0.34
# ROUGE-1 F1 Score: 0.33333333333333337
# ROUGE-2 F1 Score: 0.0625
# ROUGE-L F1 Score: 0.18181818181818182
